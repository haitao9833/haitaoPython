# %% [markdown]
# # 默认代码

# %%
# %%capture
# %run "file_Tool.ipynb"

# %%
# %%capture
# %run "viz_Tool.ipynb"

# %%
# %%capture
# %run "model_Tool.ipynb"

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# # `2` 维 --> `1` 维

# %%
data = read_ex(r'data\肿瘤数据.xlsx')[['最大半径' , '平均灰度值']]
allCol(data)
data.head()
# Out:
# (569行 ,  2 列)
#       列名           数据类型  NaN 个数  NaN 占比
# 0   最大半径  numpy.float64       0   0.00%
# 1  平均灰度值  numpy.float64       0   0.00%
#     最大半径  平均灰度值
# 0  25.38  17.33
# 1  24.99  23.41
# 2  23.57  25.53
# 3  14.91  26.50
# 4  22.54  16.67

# %%
# n_components 就是降维后的维度数

pca = PCA(n_components = 1)
pca.fit(data)
res = pca.transform(data)

# %%
print(type(res))
print(res.shape)
# Out:
# <class 'numpy.ndarray'>
# (569, 1)

# %%
res[:10]
# Out:
# array([[-3.09148319],
#        [ 2.09336692],
#        [ 3.2983009 ],
#        [ 0.08818071],
#        [-5.00778706],
#        [-2.07681047],
#        [ 4.85485407],
#        [ 2.54571171],
#        [ 4.09516867],
#        [12.69211588]])

# %%
data.mean()
# Out:
# 最大半径     16.269190
# 平均灰度值    25.677223
# dtype: float64

# %%
# 线性降维方程
# 注意，第一列和第二列需要分别减去均值，才是 X1 、X2

print(f'X_new_1 = {pca.components_[0][0]:6.3f} * X1 + {pca.components_[0][1]:6.3f} * X2')
# Out:
# X_new_1 =  0.470 * X1 +  0.883 * X2

# %%
pca_func(pca)
# Out:
# X_new_1 =  0.470 * X1 +  0.883 * X2

# %% [markdown]
# #  `n` 维 --> `k` 维

# %% [markdown]
# ## 读取数据

# %%
data = read_ex(r'data\肿瘤数据.xlsx')
allCol(data)
data.head()
# Out:
# (569行 ,  7 列)
#       列名           数据类型  NaN 个数  NaN 占比
# 0   最大周长  numpy.float64       0   0.00%
# 1  最大凹陷度  numpy.float64       0   0.00%
# 2  平均凹陷度  numpy.float64       0   0.00%
# 3   最大面积  numpy.float64       0   0.00%
# 4   最大半径  numpy.float64       0   0.00%
# 5  平均灰度值  numpy.float64       0   0.00%
# 6   肿瘤性质  numpy.float64       0   0.00%
#      最大周长   最大凹陷度    平均凹陷度    最大面积   最大半径  平均灰度值  肿瘤性质
# 0  184.60  0.2654  0.14710  2019.0  25.38  17.33     0
# 1  158.80  0.1860  0.07017  1956.0  24.99  23.41     0
# 2  152.50  0.2430  0.12790  1709.0  23.57  25.53     1
# 3   98.87  0.2575  0.10520   567.7  14.91  26.50     0
# 4  152.20  0.1625  0.10430  1575.0  22.54  16.67     0

# %% [markdown]
# ## 量级差距
# >- 归一化，消除量级差距

# %%
data = standardize_mean_var(data)
allCol(data)
data.head()
# Out:
# (569行 ,  7 列)
#       列名           数据类型  NaN 个数  NaN 占比
# 0   最大周长  numpy.float64       0   0.00%
# 1  最大凹陷度  numpy.float64       0   0.00%
# 2  平均凹陷度  numpy.float64       0   0.00%
# 3   最大面积  numpy.float64       0   0.00%
# 4   最大半径  numpy.float64       0   0.00%
# 5  平均灰度值  numpy.float64       0   0.00%
# 6   肿瘤性质  numpy.float64       0   0.00%
#        最大周长     最大凹陷度     平均凹陷度      最大面积      最大半径     平均灰度值      肿瘤性质
# 0  2.303601  2.296076  2.532475  2.001237  1.886690 -1.359293 -1.302568
# 1  1.535126  1.087084  0.548144  1.890489  1.805927 -0.369203 -1.302568
# 2  1.347475  1.955000  2.037231  1.456285  1.511870 -0.023974  0.767714
# 3 -0.249939  2.175786  1.451707 -0.550021 -0.281464  0.133984 -1.302568
# 4  1.338539  0.729259  1.428493  1.220724  1.298575 -1.466770 -1.302568

# %% [markdown]
# ## 降维 `2D`

# %%
pca = PCA(n_components = 2)
pca.fit(data)
res2D = pca.transform(data)

# %%
print(type(res2D))
print(res2D.shape)
res2D[:10]
# Out:
# <class 'numpy.ndarray'>
# (569, 2)
# array([[ 4.6717349 , -2.42834027],
#        [ 3.21272593, -0.97529921],
#        [ 3.05410979, -1.11391342],
#        [ 1.49299077,  0.08515596],
#        [ 2.64012946, -1.96995865],
#        [ 0.89029043, -0.23736443],
#        [ 2.93202431, -0.18477211],
#        [ 1.04494579,  0.44567208],
#        [ 1.46941344,  0.75211984],
#        [ 1.63704471,  2.36101874]])

# %%
pca_func(pca)
# Out:
# X_new_1 =  0.419 * X1 +  0.389 * X2 +  0.396 * X3 +  0.405 * X4 +  0.414 * X5 +  0.199 * X6 + -0.376 * X7
# X_new_2 = -0.119 * X1 + -0.055 * X2 + -0.166 * X3 + -0.134 * X4 + -0.120 * X5 +  0.950 * X6 + -0.139 * X7

# %% [markdown]
# ### `KMeans`

# %%
scatter_pre , scatter_after =  model_Cluster(
    pd.DataFrame(res2D) , 
    5 , 33 , 
    0.5 , 0.5 , 
    '二维一条龙'
)

# %%
scatter_pre.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4ed03cd40e9741f58389a2370b075465" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4ed03cd40e9741f58389a2370b075465 = echarts.init(
#                     document.getElementById('4ed03cd40e9741f58389a2370b075465'), 'white', {renderer: 'canvas'});
#                 var option_4ed03cd40e9741f58389a2370b075465 = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#00BFFF",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u4e8c\u7ef4\u4e00\u6761\u9f99",
#             "symbolSize": 15,
#             "data": [
#                 [
#                     4.671734899936769,
#                     -2.428340266195805
#                 ],
#                 [
#                     3.212725928136092,
#                     -0.9752992117239012
#                 ],
#                 [
#                     3.054109790006468,
#                     -1.1139134181136634
#                 ],
#                 [
#                     1.492990770524937,
#                     0.08515596187573843
#                 ],
#                 [
#                     2.640129461612239,
#                     -1.969958647315162
#                 ],
#                 [
#                     0.8902904313041226,
#                     -0.23736443334203142
#                 ],
#                 [
#                     2.932024307246462,
#                     -0.18477211196158874
#                 ],
#                 [
#                     1.0449457913563427,
#                     0.44567208426937355
#                 ],
#                 [
#                     1.4694134368574785,
#                     0.7521198369428477
#                 ],
#                 [
#                     1.6370447098583443,
#                     2.3610187357670296
#                 ],
#                 [
#                     1.1559490152143361,
#                     1.335167447167318
#                 ],
#                 [
#                     2.128409593298964,
#                     -0.006167087626742097
#                 ],
#                 [
#                     2.9159240714300796,
#                     0.13842108452724064
#                 ],
#                 [
#                     0.691291881216027,
#                     0.4401373446149286
#                 ],
#                 [
#                     1.4260794519878532,
#                     1.0065497055537518
#                 ],
#                 [
#                     1.8050446013668622,
#                     1.6961329068791673
#                 ],
#                 [
#                     1.5946257432692041,
#                     0.74377621890282
#                 ],
#                 [
#                     2.857074101112305,
#                     0.4463812278554331
#                 ],
#                 [
#                     4.884635302183118,
#                     -0.2317090513893558
#                 ],
#                 [
#                     -0.7382684515755628,
#                     -1.0114953633008925
#                 ],
#                 [
#                     -1.3552287827233043,
#                     -0.6553993920076958
#                 ],
#                 [
#                     -2.657090384451635,
#                     -1.0588295953437927
#                 ],
#                 [
#                     1.959252541393094,
#                     -1.2848589428761885
#                 ],
#                 [
#                     5.052747437872846,
#                     0.4646056290720398
#                 ],
#                 [
#                     4.373435732471679,
#                     0.011765892372013496
#                 ],
#                 [
#                     3.6030653596160103,
#                     -1.4354547090388157
#                 ],
#                 [
#                     2.3678668020003495,
#                     0.9583376345112913
#                 ],
#                 [
#                     2.2461879997017524,
#                     -0.08917981303511378
#                 ],
#                 [
#                     2.905170991486591,
#                     1.3089668431858081
#                 ],
#                 [
#                     1.6986910780125422,
#                     -1.201988716727536
#                 ],
#                 [
#                     3.7628903254884727,
#                     0.5419564161980523
#                 ],
#                 [
#                     1.0395260452238104,
#                     0.45440773903134385
#                 ],
#                 [
#                     2.9269934503141957,
#                     0.48270709035113896
#                 ],
#                 [
#                     3.3283952661320577,
#                     0.211146679454824
#                 ],
#                 [
#                     2.184366970557185,
#                     -0.03507502709492669
#                 ],
#                 [
#                     2.004038509216487,
#                     0.3254303931880608
#                 ],
#                 [
#                     0.9128748142786904,
#                     0.847279476089409
#                 ],
#                 [
#                     -1.7417205240200693,
#                     -0.17795356799218873
#                 ],
#                 [
#                     -0.6215095988635053,
#                     0.3812705479030387
#                 ],
#                 [
#                     1.051917165538072,
#                     0.16852718008209727
#                 ],
#                 [
#                     0.170843110356984,
#                     1.0613969472189584
#                 ],
#                 [
#                     0.24144923036745808,
#                     1.8634452695120045
#                 ],
#                 [
#                     4.1418709425919955,
#                     0.3844653967455936
#                 ],
#                 [
#                     1.0861058924800493,
#                     0.40273852249134556
#                 ],
#                 [
#                     0.8107968552288196,
#                     0.8192836923057438
#                 ],
#                 [
#                     3.200068371821264,
#                     -1.2986647451093405
#                 ],
#                 [
#                     -3.079930294188813,
#                     0.08727608543279135
#                 ],
#                 [
#                     1.177562168658996,
#                     0.4083573488437249
#                 ],
#                 [
#                     -1.6038502455348804,
#                     -0.549437306495354
#                 ],
#                 [
#                     -0.4917016686673103,
#                     0.9970792952509454
#                 ],
#                 [
#                     -1.9758494687406523,
#                     0.380830900555236
#                 ],
#                 [
#                     -1.2992390802805451,
#                     -0.19962487010749352
#                 ],
#                 [
#                     -1.914931398522089,
#                     -0.3383681134392124
#                 ],
#                 [
#                     2.161126033735684,
#                     -0.6281733882028747
#                 ],
#                 [
#                     1.1461806528978762,
#                     1.0280198851301223
#                 ],
#                 [
#                     -1.8423285321103806,
#                     -0.18374227633803095
#                 ],
#                 [
#                     4.078916407271317,
#                     -0.46066644368433135
#                 ],
#                 [
#                     1.7070293647975514,
#                     0.6678509760947251

# %%
scatter_after.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a7ebd30c150a437c8dfb12b4c031d982" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a7ebd30c150a437c8dfb12b4c031d982 = echarts.init(
#                     document.getElementById('a7ebd30c150a437c8dfb12b4c031d982'), 'white', {renderer: 'canvas'});
#                 var option_a7ebd30c150a437c8dfb12b4c031d982 = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#FF0000",
#         "#1E90FF",
#         "#54FF9F",
#         "#FFDAB9",
#         "#ffff00",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "Class-0",
#             "symbolSize": 15,
#             "data": [
#                 [
#                     -0.7382684515755628,
#                     -1.0114953633008925
#                 ],
#                 [
#                     -1.3552287827233043,
#                     -0.6553993920076958
#                 ],
#                 [
#                     -2.657090384451635,
#                     -1.0588295953437927
#                 ],
#                 [
#                     -1.7417205240200693,
#                     -0.17795356799218873
#                 ],
#                 [
#                     -3.079930294188813,
#                     0.08727608543279135
#                 ],
#                 [
#                     -1.6038502455348804,
#                     -0.549437306495354
#                 ],
#                 [
#                     -1.2992390802805451,
#                     -0.19962487010749352
#                 ],
#                 [
#                     -1.914931398522089,
#                     -0.3383681134392124
#                 ],
#                 [
#                     -1.8423285321103806,
#                     -0.18374227633803095
#                 ],
#                 [
#                     -2.0393417512655927,
#                     -0.18680406749202397
#                 ],
#                 [
#                     -3.0606964323305936,
#                     -0.9823712138869264
#                 ],
#                 [
#                     -2.730284681243025,
#                     -0.7666113247471998
#                 ],
#                 [
#                     -2.6148039171540773,
#                     -0.49613223632910947
#                 ],
#                 [
#                     -1.8840664653982462,
#                     0.06049180792006468
#                 ],
#                 [
#                     -1.5100580247267141,
#                     -0.17593591157939384
#                 ],
#                 [
#                     -1.759932285224474,
#                     -0.6652363861438456
#                 ],
#                 [
#                     -2.7571126326472157,
#                     -1.0504124763420095
#                 ],
#                 [
#                     -1.39805856295151,
#                     -0.17324452340984628
#                 ],
#                 [
#                     -1.3677971848129808,
#                     -2.0087045967729837
#                 ],
#                 [
#                     -1.3388859778439137,
#                     0.06674404294910892
#                 ],
#                 [
#                     -0.20738327267870516,
#                     -0.5098600843168761
#                 ],
#                 [
#                     -0.1812220684821504,
#                     -1.3630825991122335
#                 ],
#                 [
#                     -0.7738043404548914,
#                     -0.4943103523773032
#                 ],
#                 [
#                     -1.85506627915837,
#                     -0.4466365548562679
#                 ],
#                 [
#                     -1.7409174536742735,
#                     -1.080452251727631
#                 ],
#                 [
#                     -3.5852797097917053,
#                     -0.17677275944206292
#                 ],
#                 [
#                     -2.389221326160849,
#                     0.10236134051940439
#                 ],
#                 [
#                     -2.3629841648202885,
#                     -0.19535673856591898
#                 ],
#                 [
#                     -0.9356728620229608,
#                     0.037913702943732176
#                 ],
#                 [
#                     -0.050942618255450774,
#                     -0.49705166492608494
#                 ],
#                 [
#                     -2.11578905620807,
#                     -0.06697005721404493
#                 ],
#                 [
#                     -2.3729127890708446,
#                     -0.45095719030932474
#                 ],
#                 [
#                     -2.852915664059379,
#                     -0.7931153430820573
#                 ],
#                 [
#                     -1.8359441440686572,
#                     -1.2341748352054611
#                 ],
#                 [
#                     -0.6686149785381197,
#                     -1.5899324314080137
#                 ],
#                 [
#                     -1.2839345899504784,
#                     -0.28648870843830926
#                 ],
#                 [
#                     -1.3798733009812534,
#                     -0.13680399766269585
#                 ],
#                 [
#                     -0.10527341751159999,
#                     -1.3863077679753872
#                 ],
#                 [
#                     -1.630892302495279,
#                     -1.0022667421566145
#                 ],
#                 [
#                     -0.03215025017600615,
#                     -1.230980591625847
#                 ],
#                 [
#                     -1.7676176236317758,
#                     -0.26703822671002697
#                 ],
#                 [
#                     -1.8625065721774774,
#                     -1.2889310389086404
#                 ],
#                 [
#                     -3.2174356179660695,
#                     -1.1803410022624785
#                 ],
#                 [
#                     -1.1252652954110856,
#                     -0.4790256057623647
#                 ],
#                 [
#                     -2.3959366617444218,
#                     -0.31458158977793665
#                 ],
#                 [
#                     -1.8930860957880322,
#                     -1.1592059407548356
#                 ],
#                 [
#                     -0.6661924562580339,
#                     -0.038496277172572
#                 ],
#                 [
#                     -0.2442253479163705,
#                     -1.0417428003187534
#                 ],
#                 [
#                     -1.3944504709020022,
#                     -0.31111146756586616
#                 ],
#                 [
#                     -1.4485590856822939,
#                     -0.03645885672076129
#                 ],
#                 [
#                     -1.1928218310997876,
#                     -0.8492854662317434
#                 ],
#                 [
#                     -2.329318398673029,
#                     -1.0544355178701628
#                 ],
#                 [
#                     -1.0962481064620382,
#                     -0.7137685308560444
#                 ],
#                 [
#                     -1.8911340374421266,
#                     -0.8264710969551651
#                 ],
#                 [
#                     -2.3996055786953328,
#                     -0.7216858148644055
#                 ],
#                 [
#                     -2.6152877490814443,
#                     -1.6802281343197751
#                 ],
#                 [
#                     -0.7736961331659336,

# %% [markdown]
# ## 降维 `3D`

# %%
pca = PCA(n_components = 3)
pca.fit(data)
res3D = pca.transform(data)

# %%
print(type(res3D))
print(res3D.shape)
res3D[:10]
# Out:
# <class 'numpy.ndarray'>
# (569, 3)
# array([[ 4.6717349 , -2.42834027, -0.45137339],
#        [ 3.21272593, -0.97529921,  0.71330277],
#        [ 3.05410979, -1.11391342,  0.12920967],
#        [ 1.49299077,  0.08515596, -2.57792179],
#        [ 2.64012946, -1.96995865, -0.09556897],
#        [ 0.89029043, -0.23736443, -1.49843699],
#        [ 2.93202431, -0.18477211,  0.19771583],
#        [ 1.04494579,  0.44567208, -0.75984315],
#        [ 1.46941344,  0.75211984, -1.72793176],
#        [ 1.63704471,  2.36101874, -1.7268708 ]])

# %%
pca_func(pca)
# Out:
# X_new_1 =  0.419 * X1 +  0.389 * X2 +  0.396 * X3 +  0.405 * X4 +  0.414 * X5 +  0.199 * X6 + -0.376 * X7
# X_new_2 = -0.119 * X1 + -0.055 * X2 + -0.166 * X3 + -0.134 * X4 + -0.120 * X5 +  0.950 * X6 + -0.139 * X7
# X_new_3 =  0.301 * X1 + -0.530 * X2 + -0.367 * X3 +  0.462 * X4 +  0.371 * X5 +  0.108 * X6 +  0.363 * X7

# %% [markdown]
# ### `KMeans`

# %%
data = pd.DataFrame(res3D , columns = ['一' , '二' , '三'])
allCol(data)
data.head()
# Out:
# (569行 ,  3 列)
#   列名           数据类型  NaN 个数  NaN 占比
# 0  一  numpy.float64       0   0.00%
# 1  二  numpy.float64       0   0.00%
# 2  三  numpy.float64       0   0.00%
#           一         二         三
# 0  4.671735 -2.428340 -0.451373
# 1  3.212726 -0.975299  0.713303
# 2  3.054110 -1.113913  0.129210
# 3  1.492991  0.085156 -2.577922
# 4  2.640129 -1.969959 -0.095569

# %%
# 初始分布

draw_Scatter3D(
    data['一'] , 
    data['二'] , 
    data['三'] , 
    '一' , '二' , '三' , 
    '初始分布'
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/v5/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="b4e648bbe9fc41558372332982ccea21" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_b4e648bbe9fc41558372332982ccea21 = echarts.init(
#                     document.getElementById('b4e648bbe9fc41558372332982ccea21'), 'white', {renderer: 'canvas'});
#                 var option_b4e648bbe9fc41558372332982ccea21 = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "name": "\u521d\u59cb\u5206\u5e03",
#             "data": [
#                 [
#                     4.671734899936769,
#                     -2.4283402661958062,
#                     -0.4513733894539356
#                 ],
#                 [
#                     3.2127259281360923,
#                     -0.9752992117239018,
#                     0.713302773336922
#                 ],
#                 [
#                     3.0541097900064678,
#                     -1.113913418113664,
#                     0.12920966895187605
#                 ],
#                 [
#                     1.4929907705249368,
#                     0.08515596187573876,
#                     -2.5779217916802866
#                 ],
#                 [
#                     2.6401294616122395,
#                     -1.969958647315163,
#                     -0.09556896734202777
#                 ],
#                 [
#                     0.8902904313041226,
#                     -0.23736443334203133,
#                     -1.4984369908223047
#                 ],
#                 [
#                     2.9320243072464622,
#                     -0.184772111961589,
#                     0.19771582612881491
#                 ],
#                 [
#                     1.044945791356343,
#                     0.44567208426937377,
#                     -0.7598431494438531
#                 ],
#                 [
#                     1.4694134368574785,
#                     0.7521198369428481,
#                     -1.7279317557402205
#                 ],
#                 [
#                     1.6370447098583445,
#                     2.3610187357670305,
#                     -1.7268707966175318
#                 ],
#                 [
#                     1.1559490152143366,
#                     1.3351674471673183,
#                     0.5311170218526152
#                 ],
#                 [
#                     2.1284095932989646,
#                     -0.00616708762674212,
#                     -0.22274762221784725
#                 ],
#                 [
#                     2.91592407143008,
#                     0.13842108452724056,
#                     -0.3703987404056059
#                 ],
#                 [
#                     0.6912918812160274,
#                     0.4401373446149288,
#                     -0.37785008040596446
#                 ],
#                 [
#                     1.4260794519878535,
#                     1.0065497055537522,
#                     -1.7446605039967102
#                 ],
#                 [
#                     1.8050446013668624,
#                     1.696132906879168,
#                     -0.6689687173809988
#                 ],
#                 [
#                     1.5946257432692044,
#                     0.7437762189028203,
#                     -0.22108796836440245
#                 ],
#                 [
#                     2.8570741011123055,
#                     0.4463812278554332,
#                     -0.6521185876681648
#                 ],
#                 [
#                     4.884635302183119,
#                     -0.2317090513893562,
#                     0.9719604605483377
#                 ],
#                 [
#                     -0.7382684515755631,
#                     -1.0114953633008927,
#                     -0.2324619077314563
#                 ],
#                 [
#                     -1.3552287827233047,
#                     -0.6553993920076959,
#                     0.254511405042759
#                 ],
#                 [
#                     -2.657090384451635,
#                     -1.0588295953437932,
#                     -0.5084273495092654
#                 ],
#                 [
#                     1.9592525413930935,
#                     -1.284858942876189,
#                     -1.6766242499891508
#                 ],
#                 [
#                     5.052747437872846,
#                     0.4646056290720395,
#                     1.771519031023598
#                 ],
#                 [
#                     4.3734357324716795,
#                     0.011765892372013196,
#                     0.9491432976936832
#                 ],
#                 [
#                     3.6030653596160107,
#                     -1.4354547090388163,
#                     -1.21082186929525
#                 ],
#                 [
#                     2.36786680200035,
#                     0.9583376345112918,
#                     -1.7109061777200725
#                 ],
#                 [
#                     2.246187999701753,
#                     -0.08917981303511391,
#                     0.1115520225800121
#                 ],
#                 [
#                     2.9051709914865915,
#                     1.3089668431858084,
#                     -0.3538239599859707
#                 ],
#                 [
#                     1.6986910780125422,
#                     -1.2019887167275365,
#                     -0.3057092956082265
#                 ],
#                 [
#                     3.762890325488473,
#                     0.5419564161980523,
#                     0.03760454222432877
#                 ],
#                 [
#                     1.0395260452238106,
#                     0.45440773903134407,
#                     -0.6223182225577726
#                 ],
#                 [
#                     2.926993450314196,
#                     0.4827070903511391,
#                     -0.6138181082044448
#                 ],
#                 [
#                     3.328395266132059,
#                     0.21114667945482402,
#                     0.693931879651898
#                 ],
#                 [
#                     2.1843669705571855,
#                     -0.035075027094926714,
#                     -0.4562851952706978
#                 ],
#                 [
#                     2.0040385092164876,
#                     0.32543039318806083,
#                     -0.2539188580391291
#                 ],
#                 [
#                     0.9128748142786908,
#                     0.8472794760894093,
#                     -0.7147563914517975
#                 ],
#                 [
#                     -1.7417205240200695,
#                     -0.17795356799218878,
#                     0.23131100412532676
#                 ],
#                 [
#                     -0.6215095988635051,
#                     0.38127054790303894,
#                     0.0477687225296928
#                 ],
#                 [
#                     1.051917165538072,
#                     0.16852718008209752,
#                     -1.5857822928194107
#                 ],
#                 [
#                     0.17084311035698446,
#                     1.0613969472189588,
#                     -0.2374751495438757
#                 ],
#                 [
#                     0.24144923036745827,
#                     1.8634452695120054,
#                     -1.3406233959150016
#                 ],
#                 [
#                     4.1418709425919955,
#                     0.38446539674559344,

# %%
model = KMeans(n_clusters = 3 , random_state = 529833)
model.fit(data)
# Out:
# KMeans(n_clusters=3, random_state=529833)

# %%
data['分类'] = model.labels_
allCol(data)
data.head()
# Out:
# (569行 ,  4 列)
#    列名           数据类型  NaN 个数  NaN 占比
# 0   一  numpy.float64       0   0.00%
# 1   二  numpy.float64       0   0.00%
# 2   三  numpy.float64       0   0.00%
# 3  分类  numpy.float64       0   0.00%
#           一         二         三  分类
# 0  4.671735 -2.428340 -0.451373   2
# 1  3.212726 -0.975299  0.713303   2
# 2  3.054110 -1.113913  0.129210   2
# 3  1.492991  0.085156 -2.577922   1
# 4  2.640129 -1.969959 -0.095569   2

# %%
val_cnt(data , '分类')
# Out:
#    分类  cnt proportion
# 0   0  359     63.09%
# 1   1  130     22.85%
# 2   2   80     14.06%

# %%
XYZ = [
    (
        float(data['一'].iloc[i]) , 
        float(data['二'].iloc[i]) , 
        float(data['三'].iloc[i])
    )
    for i in range(len(data))
]

labelsInt = [int(la) for la in list(data['分类'])]

LABELS_DICT_Int = {
    0 : '#abd9e9' , 
    1 : 'purple' , 
    2 : '#fdae61' ,
    3 : '#f46d43' , 
    4 : '#4575b4' , 
}

# %%
draw_Scatter3D_clf(
    XYZ , 
    labelsInt , LABELS_DICT_Int , 
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/v5/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="fb739efde7af477fbd4456426feb8238" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_fb739efde7af477fbd4456426feb8238 = echarts.init(
#                     document.getElementById('fb739efde7af477fbd4456426feb8238'), 'white', {renderer: 'canvas'});
#                 var option_fb739efde7af477fbd4456426feb8238 = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "name": "\u56fe\u4f8b\u540d\u79f0",
#             "data": [
#                 {
#                     "value": [
#                         4.671734899936769,
#                         -2.4283402661958062,
#                         -0.4513733894539356
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         3.2127259281360923,
#                         -0.9752992117239018,
#                         0.713302773336922
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         3.0541097900064678,
#                         -1.113913418113664,
#                         0.12920966895187605
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.4929907705249368,
#                         0.08515596187573876,
#                         -2.5779217916802866
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.6401294616122395,
#                         -1.969958647315163,
#                         -0.09556896734202777
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         0.8902904313041226,
#                         -0.23736443334203133,
#                         -1.4984369908223047
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.9320243072464622,
#                         -0.184772111961589,
#                         0.19771582612881491
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.044945791356343,
#                         0.44567208426937377,
#                         -0.7598431494438531
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.4694134368574785,
#                         0.7521198369428481,
#                         -1.7279317557402205
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.6370447098583445,
#                         2.3610187357670305,
#                         -1.7268707966175318
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.1559490152143366,
#                         1.3351674471673183,
#                         0.5311170218526152
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.1284095932989646,
#                         -0.00616708762674212,
#                         -0.22274762221784725
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.91592407143008,
#                         0.13842108452724056,
#                         -0.3703987404056059
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         0.6912918812160274,
#                         0.4401373446149288,
#                         -0.37785008040596446
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.4260794519878535,
#                         1.0065497055537522,
#                         -1.7446605039967102
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.8050446013668624,
#                         1.696132906879168,
#                         -0.6689687173809988
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.5946257432692044,
#                         0.7437762189028203,
#                         -0.22108796836440245
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.8570741011123055,
#                         0.4463812278554332,
#                         -0.6521185876681648
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         4.884635302183119,
#                         -0.2317090513893562,
#                         0.9719604605483377
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         -0.7382684515755631,
#                         -1.0114953633008927,
#                         -0.2324619077314563
#                     ],
#                     "itemStyle": {
#                         "color": "#abd9e9"
#                     }
#                 },
#                 {
#                     "value": [
#                         -1.3552287827233047,
#                         -0.6553993920076959,
#                         0.254511405042759
#                     ],
#                     "itemStyle": {
