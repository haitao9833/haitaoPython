# %% [markdown]
# # 默认代码

# %%
# %%capture
# %run "file_Tool.ipynb"

# %%
# %%capture
# %run "viz_Tool.ipynb"

# %%
# %%capture
# %run "model_Tool.ipynb"

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# # `2` 维 --> `1` 维

# %%
data = read_ex(r'data\肿瘤数据.xlsx')[['最大半径' , '平均灰度值']]
allCol(data)
data.head()
# Out:
# (569行 ,  2 列)
#       列名           数据类型  NaN 个数  NaN 占比
# 0   最大半径  numpy.float64       0   0.00%
# 1  平均灰度值  numpy.float64       0   0.00%
#     最大半径  平均灰度值
# 0  25.38  17.33
# 1  24.99  23.41
# 2  23.57  25.53
# 3  14.91  26.50
# 4  22.54  16.67

# %%
# n_components 就是降维后的维度数

pca = PCA(n_components = 1)
pca.fit(data)
res = pca.transform(data)

# %%
print(type(res))
print(res.shape)
# Out:
# <class 'numpy.ndarray'>
# (569, 1)

# %%
res[:10]
# Out:
# array([[-3.09148319],
#        [ 2.09336692],
#        [ 3.2983009 ],
#        [ 0.08818071],
#        [-5.00778706],
#        [-2.07681047],
#        [ 4.85485407],
#        [ 2.54571171],
#        [ 4.09516867],
#        [12.69211588]])

# %%
data.mean()
# Out:
# 最大半径     16.269190
# 平均灰度值    25.677223
# dtype: float64

# %%
# 线性降维方程
# 注意，第一列和第二列需要分别减去均值，才是 X1 、X2

print(f'X_new_1 = {pca.components_[0][0]:6.3f} * X1 + {pca.components_[0][1]:6.3f} * X2')
# Out:
# X_new_1 =  0.470 * X1 +  0.883 * X2

# %%
pca_func(pca)
# Out:
# X_new_1 =  0.470 * X1 +  0.883 * X2

# %% [markdown]
# #  `n` 维 --> `k` 维

# %% [markdown]
# ## 读取数据

# %%
data = read_ex(r'data\肿瘤数据.xlsx')
allCol(data)
data.head()
# Out:
# (569行 ,  7 列)
#       列名           数据类型  NaN 个数  NaN 占比
# 0   最大周长  numpy.float64       0   0.00%
# 1  最大凹陷度  numpy.float64       0   0.00%
# 2  平均凹陷度  numpy.float64       0   0.00%
# 3   最大面积  numpy.float64       0   0.00%
# 4   最大半径  numpy.float64       0   0.00%
# 5  平均灰度值  numpy.float64       0   0.00%
# 6   肿瘤性质  numpy.float64       0   0.00%
#      最大周长   最大凹陷度    平均凹陷度    最大面积   最大半径  平均灰度值  肿瘤性质
# 0  184.60  0.2654  0.14710  2019.0  25.38  17.33     0
# 1  158.80  0.1860  0.07017  1956.0  24.99  23.41     0
# 2  152.50  0.2430  0.12790  1709.0  23.57  25.53     1
# 3   98.87  0.2575  0.10520   567.7  14.91  26.50     0
# 4  152.20  0.1625  0.10430  1575.0  22.54  16.67     0

# %% [markdown]
# ## 量级差距
# >- 归一化，消除量级差距

# %%
data = standardize_mean_var(data)
allCol(data)
data.head()
# Out:
# (569行 ,  7 列)
#       列名           数据类型  NaN 个数  NaN 占比
# 0   最大周长  numpy.float64       0   0.00%
# 1  最大凹陷度  numpy.float64       0   0.00%
# 2  平均凹陷度  numpy.float64       0   0.00%
# 3   最大面积  numpy.float64       0   0.00%
# 4   最大半径  numpy.float64       0   0.00%
# 5  平均灰度值  numpy.float64       0   0.00%
# 6   肿瘤性质  numpy.float64       0   0.00%
#        最大周长     最大凹陷度     平均凹陷度      最大面积      最大半径     平均灰度值      肿瘤性质
# 0  2.303601  2.296076  2.532475  2.001237  1.886690 -1.359293 -1.302568
# 1  1.535126  1.087084  0.548144  1.890489  1.805927 -0.369203 -1.302568
# 2  1.347475  1.955000  2.037231  1.456285  1.511870 -0.023974  0.767714
# 3 -0.249939  2.175786  1.451707 -0.550021 -0.281464  0.133984 -1.302568
# 4  1.338539  0.729259  1.428493  1.220724  1.298575 -1.466770 -1.302568

# %% [markdown]
# ## 降维 `2D`

# %%
pca = PCA(n_components = 2)
pca.fit(data)
res2D = pca.transform(data)

# %%
print(type(res2D))
print(res2D.shape)
res2D[:10]
# Out:
# <class 'numpy.ndarray'>
# (569, 2)
# array([[ 4.6717349 , -2.42834027],
#        [ 3.21272593, -0.97529921],
#        [ 3.05410979, -1.11391342],
#        [ 1.49299077,  0.08515596],
#        [ 2.64012946, -1.96995865],
#        [ 0.89029043, -0.23736443],
#        [ 2.93202431, -0.18477211],
#        [ 1.04494579,  0.44567208],
#        [ 1.46941344,  0.75211984],
#        [ 1.63704471,  2.36101874]])

# %%
pca_func(pca)
# Out:
# X_new_1 =  0.419 * X1 +  0.389 * X2 +  0.396 * X3 +  0.405 * X4 +  0.414 * X5 +  0.199 * X6 + -0.376 * X7
# X_new_2 = -0.119 * X1 + -0.055 * X2 + -0.166 * X3 + -0.134 * X4 + -0.120 * X5 +  0.950 * X6 + -0.139 * X7

# %% [markdown]
# ### `KMeans`

# %%
scatter_pre , scatter_after =  model_Cluster(
    pd.DataFrame(res2D) , 
    5 , 33 , 
    0.5 , 0.5 , 
    '二维一条龙'
)

# %%
scatter_pre.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="35d4d312e4e947bcabbd0c894428312a" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_35d4d312e4e947bcabbd0c894428312a = echarts.init(
#                     document.getElementById('35d4d312e4e947bcabbd0c894428312a'), 'white', {renderer: 'canvas'});
#                 var option_35d4d312e4e947bcabbd0c894428312a = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#00BFFF",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u4e8c\u7ef4\u4e00\u6761\u9f99",
#             "symbolSize": 15,
#             "data": [
#                 [
#                     4.671734899936769,
#                     -2.428340266195806
#                 ],
#                 [
#                     3.2127259281360923,
#                     -0.9752992117239015
#                 ],
#                 [
#                     3.0541097900064678,
#                     -1.1139134181136632
#                 ],
#                 [
#                     1.492990770524937,
#                     0.08515596187573835
#                 ],
#                 [
#                     2.640129461612239,
#                     -1.9699586473151627
#                 ],
#                 [
#                     0.8902904313041228,
#                     -0.23736443334203167
#                 ],
#                 [
#                     2.9320243072464613,
#                     -0.18477211196158888
#                 ],
#                 [
#                     1.0449457913563431,
#                     0.44567208426937344
#                 ],
#                 [
#                     1.4694134368574787,
#                     0.7521198369428476
#                 ],
#                 [
#                     1.6370447098583445,
#                     2.3610187357670296
#                 ],
#                 [
#                     1.1559490152143366,
#                     1.335167447167318
#                 ],
#                 [
#                     2.1284095932989646,
#                     -0.00616708762674224
#                 ],
#                 [
#                     2.9159240714300796,
#                     0.1384210845272405
#                 ],
#                 [
#                     0.6912918812160275,
#                     0.44013734461492837
#                 ],
#                 [
#                     1.4260794519878537,
#                     1.0065497055537518
#                 ],
#                 [
#                     1.8050446013668624,
#                     1.6961329068791675
#                 ],
#                 [
#                     1.5946257432692046,
#                     0.74377621890282
#                 ],
#                 [
#                     2.857074101112305,
#                     0.44638122785543305
#                 ],
#                 [
#                     4.884635302183118,
#                     -0.23170905138935577
#                 ],
#                 [
#                     -0.738268451575563,
#                     -1.0114953633008925
#                 ],
#                 [
#                     -1.3552287827233045,
#                     -0.6553993920076957
#                 ],
#                 [
#                     -2.6570903844516347,
#                     -1.0588295953437932
#                 ],
#                 [
#                     1.959252541393094,
#                     -1.2848589428761887
#                 ],
#                 [
#                     5.052747437872846,
#                     0.4646056290720398
#                 ],
#                 [
#                     4.373435732471679,
#                     0.011765892372013465
#                 ],
#                 [
#                     3.6030653596160107,
#                     -1.435454709038816
#                 ],
#                 [
#                     2.36786680200035,
#                     0.9583376345112914
#                 ],
#                 [
#                     2.2461879997017524,
#                     -0.08917981303511392
#                 ],
#                 [
#                     2.9051709914865906,
#                     1.3089668431858081
#                 ],
#                 [
#                     1.6986910780125424,
#                     -1.2019887167275363
#                 ],
#                 [
#                     3.7628903254884722,
#                     0.541956416198052
#                 ],
#                 [
#                     1.0395260452238109,
#                     0.45440773903134374
#                 ],
#                 [
#                     2.926993450314196,
#                     0.48270709035113885
#                 ],
#                 [
#                     3.328395266132058,
#                     0.21114667945482396
#                 ],
#                 [
#                     2.1843669705571855,
#                     -0.03507502709492678
#                 ],
#                 [
#                     2.0040385092164876,
#                     0.3254303931880607
#                 ],
#                 [
#                     0.9128748142786909,
#                     0.8472794760894088
#                 ],
#                 [
#                     -1.7417205240200695,
#                     -0.1779535679921887
#                 ],
#                 [
#                     -0.6215095988635047,
#                     0.3812705479030383
#                 ],
#                 [
#                     1.0519171655380724,
#                     0.1685271800820972
#                 ],
#                 [
#                     0.17084311035698466,
#                     1.0613969472189584
#                 ],
#                 [
#                     0.24144923036745852,
#                     1.8634452695120045
#                 ],
#                 [
#                     4.1418709425919955,
#                     0.3844653967455937
#                 ],
#                 [
#                     1.0861058924800497,
#                     0.40273852249134545
#                 ],
#                 [
#                     0.8107968552288201,
#                     0.8192836923057437
#                 ],
#                 [
#                     3.200068371821264,
#                     -1.2986647451093403
#                 ],
#                 [
#                     -3.079930294188812,
#                     0.08727608543279121
#                 ],
#                 [
#                     1.1775621686589963,
#                     0.40835734884372477
#                 ],
#                 [
#                     -1.6038502455348804,
#                     -0.549437306495354
#                 ],
#                 [
#                     -0.4917016686673106,
#                     0.9970792952509459
#                 ],
#                 [
#                     -1.9758494687406523,
#                     0.380830900555236
#                 ],
#                 [
#                     -1.2992390802805451,
#                     -0.1996248701074934
#                 ],
#                 [
#                     -1.914931398522089,
#                     -0.3383681134392124
#                 ],
#                 [
#                     2.1611260337356843,
#                     -0.6281733882028752
#                 ],
#                 [
#                     1.1461806528978769,
#                     1.028019885130122
#                 ],
#                 [
#                     -1.8423285321103806,
#                     -0.1837422763380309
#                 ],
#                 [
#                     4.0789164072713175,
#                     -0.46066644368433135
#                 ],
#                 [
#                     1.7070293647975516,
#                     0.66785097609

# %%
scatter_after.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b59d800f31ff41e1a013ec65107301d0" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b59d800f31ff41e1a013ec65107301d0 = echarts.init(
#                     document.getElementById('b59d800f31ff41e1a013ec65107301d0'), 'white', {renderer: 'canvas'});
#                 var option_b59d800f31ff41e1a013ec65107301d0 = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#FF0000",
#         "#1E90FF",
#         "#54FF9F",
#         "#FFDAB9",
#         "#ffff00",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "Class-0",
#             "symbolSize": 15,
#             "data": [
#                 [
#                     -0.738268451575563,
#                     -1.0114953633008925
#                 ],
#                 [
#                     -1.3552287827233045,
#                     -0.6553993920076957
#                 ],
#                 [
#                     -2.6570903844516347,
#                     -1.0588295953437932
#                 ],
#                 [
#                     -1.7417205240200695,
#                     -0.1779535679921887
#                 ],
#                 [
#                     -3.079930294188812,
#                     0.08727608543279121
#                 ],
#                 [
#                     -1.6038502455348804,
#                     -0.549437306495354
#                 ],
#                 [
#                     -1.2992390802805451,
#                     -0.1996248701074934
#                 ],
#                 [
#                     -1.914931398522089,
#                     -0.3383681134392124
#                 ],
#                 [
#                     -1.8423285321103806,
#                     -0.1837422763380309
#                 ],
#                 [
#                     -2.0393417512655927,
#                     -0.18680406749202402
#                 ],
#                 [
#                     -3.0606964323305927,
#                     -0.9823712138869264
#                 ],
#                 [
#                     -2.730284681243025,
#                     -0.7666113247471998
#                 ],
#                 [
#                     -2.6148039171540773,
#                     -0.4961322363291096
#                 ],
#                 [
#                     -1.884066465398246,
#                     0.060491807920064776
#                 ],
#                 [
#                     -1.5100580247267144,
#                     -0.17593591157939373
#                 ],
#                 [
#                     -1.7599322852244739,
#                     -0.6652363861438455
#                 ],
#                 [
#                     -2.7571126326472157,
#                     -1.0504124763420097
#                 ],
#                 [
#                     -1.39805856295151,
#                     -0.17324452340984617
#                 ],
#                 [
#                     -1.3677971848129813,
#                     -2.0087045967729837
#                 ],
#                 [
#                     -1.3388859778439137,
#                     0.06674404294910903
#                 ],
#                 [
#                     -0.2073832726787056,
#                     -0.5098600843168759
#                 ],
#                 [
#                     -0.1812220684821508,
#                     -1.3630825991122335
#                 ],
#                 [
#                     -0.7738043404548917,
#                     -0.49431035237730314
#                 ],
#                 [
#                     -1.85506627915837,
#                     -0.44663655485626796
#                 ],
#                 [
#                     -1.7409174536742738,
#                     -1.080452251727631
#                 ],
#                 [
#                     -3.5852797097917053,
#                     -0.17677275944206308
#                 ],
#                 [
#                     -2.3892213261608486,
#                     0.10236134051940445
#                 ],
#                 [
#                     -2.3629841648202885,
#                     -0.19535673856591898
#                 ],
#                 [
#                     -0.9356728620229612,
#                     0.03791370294373227
#                 ],
#                 [
#                     -0.05094261825545124,
#                     -0.4970516649260848
#                 ],
#                 [
#                     -2.11578905620807,
#                     -0.0669700572140449
#                 ],
#                 [
#                     -2.3729127890708446,
#                     -0.4509571903093248
#                 ],
#                 [
#                     -2.8529156640593785,
#                     -0.7931153430820571
#                 ],
#                 [
#                     -1.8359441440686575,
#                     -1.2341748352054613
#                 ],
#                 [
#                     -0.66861497853812,
#                     -1.5899324314080139
#                 ],
#                 [
#                     -1.2839345899504784,
#                     -0.2864887084383092
#                 ],
#                 [
#                     -1.3798733009812532,
#                     -0.1368039976626958
#                 ],
#                 [
#                     -0.10527341751160046,
#                     -1.3863077679753872
#                 ],
#                 [
#                     -1.6308923024952793,
#                     -1.0022667421566147
#                 ],
#                 [
#                     -0.03215025017600656,
#                     -1.230980591625847
#                 ],
#                 [
#                     -1.767617623631776,
#                     -0.26703822671002697
#                 ],
#                 [
#                     -1.8625065721774774,
#                     -1.2889310389086406
#                 ],
#                 [
#                     -3.2174356179660686,
#                     -1.1803410022624787
#                 ],
#                 [
#                     -1.1252652954110858,
#                     -0.4790256057623647
#                 ],
#                 [
#                     -2.3959366617444213,
#                     -0.3145815897779368
#                 ],
#                 [
#                     -1.8930860957880324,
#                     -1.1592059407548359
#                 ],
#                 [
#                     -0.6661924562580342,
#                     -0.038496277172571876
#                 ],
#                 [
#                     -0.24422534791637077,
#                     -1.0417428003187534
#                 ],
#                 [
#                     -1.3944504709020022,
#                     -0.31111146756586605
#                 ],
#                 [
#                     -1.448559085682294,
#                     -0.03645885672076122
#                 ],
#                 [
#                     -1.1928218310997878,
#                     -0.8492854662317434
#                 ],
#                 [
#                     -2.3293183986730286,
#                     -1.054435517870163
#                 ],
#                 [
#                     -1.0962481064620382,
#                     -0.7137685308560443
#                 ],
#                 [
#                     -1.8911340374421264,
#                     -0.8264710969551651
#                 ],
#                 [
#                     -2.3996055786953328,
#                     -0.7216858148644055
#                 ],
#                 [
#                     -2.615287749081444,
#                     -1.6802281343197754
#                 ],
#                 [
#                     -0.7736961331659338,

# %% [markdown]
# ## 降维 `3D`

# %%
pca = PCA(n_components = 3)
pca.fit(data)
res3D = pca.transform(data)

# %%
print(type(res3D))
print(res3D.shape)
res3D[:10]
# Out:
# <class 'numpy.ndarray'>
# (569, 3)
# array([[ 4.6717349 , -2.42834027, -0.45137339],
#        [ 3.21272593, -0.97529921,  0.71330277],
#        [ 3.05410979, -1.11391342,  0.12920967],
#        [ 1.49299077,  0.08515596, -2.57792179],
#        [ 2.64012946, -1.96995865, -0.09556897],
#        [ 0.89029043, -0.23736443, -1.49843699],
#        [ 2.93202431, -0.18477211,  0.19771583],
#        [ 1.04494579,  0.44567208, -0.75984315],
#        [ 1.46941344,  0.75211984, -1.72793176],
#        [ 1.63704471,  2.36101874, -1.7268708 ]])

# %%
pca_func(pca)
# Out:
# X_new_1 =  0.419 * X1 +  0.389 * X2 +  0.396 * X3 +  0.405 * X4 +  0.414 * X5 +  0.199 * X6 + -0.376 * X7
# X_new_2 = -0.119 * X1 + -0.055 * X2 + -0.166 * X3 + -0.134 * X4 + -0.120 * X5 +  0.950 * X6 + -0.139 * X7
# X_new_3 =  0.301 * X1 + -0.530 * X2 + -0.367 * X3 +  0.462 * X4 +  0.371 * X5 +  0.108 * X6 +  0.363 * X7

# %% [markdown]
# ### `KMeans`

# %%
data = pd.DataFrame(res3D , columns = ['一' , '二' , '三'])
allCol(data)
data.head()
# Out:
# (569行 ,  3 列)
#   列名           数据类型  NaN 个数  NaN 占比
# 0  一  numpy.float64       0   0.00%
# 1  二  numpy.float64       0   0.00%
# 2  三  numpy.float64       0   0.00%
#           一         二         三
# 0  4.671735 -2.428340 -0.451373
# 1  3.212726 -0.975299  0.713303
# 2  3.054110 -1.113913  0.129210
# 3  1.492991  0.085156 -2.577922
# 4  2.640129 -1.969959 -0.095569

# %%
# 初始分布

draw_Scatter3D(
    data['一'] , 
    data['二'] , 
    data['三'] , 
    '一' , '二' , '三' , 
    '初始分布'
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/v5/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="3eece3a4c876461a903e0d331a3b3349" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_3eece3a4c876461a903e0d331a3b3349 = echarts.init(
#                     document.getElementById('3eece3a4c876461a903e0d331a3b3349'), 'white', {renderer: 'canvas'});
#                 var option_3eece3a4c876461a903e0d331a3b3349 = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "name": "\u521d\u59cb\u5206\u5e03",
#             "data": [
#                 [
#                     4.6717348999367685,
#                     -2.4283402661958045,
#                     -0.4513733894539345
#                 ],
#                 [
#                     3.2127259281360914,
#                     -0.9752992117239003,
#                     0.7133027733369214
#                 ],
#                 [
#                     3.0541097900064673,
#                     -1.113913418113663,
#                     0.12920966895187744
#                 ],
#                 [
#                     1.4929907705249363,
#                     0.0851559618757375,
#                     -2.577921791680283
#                 ],
#                 [
#                     2.6401294616122386,
#                     -1.9699586473151616,
#                     -0.09556896734202801
#                 ],
#                 [
#                     0.8902904313041222,
#                     -0.2373644333420317,
#                     -1.498436990822303
#                 ],
#                 [
#                     2.932024307246461,
#                     -0.1847721119615884,
#                     0.19771582612881503
#                 ],
#                 [
#                     1.0449457913563422,
#                     0.4456720842693733,
#                     -0.7598431494438521
#                 ],
#                 [
#                     1.4694134368574778,
#                     0.7521198369428469,
#                     -1.727931755740218
#                 ],
#                 [
#                     1.6370447098583436,
#                     2.3610187357670287,
#                     -1.7268707966175285
#                 ],
#                 [
#                     1.155949015214336,
#                     1.335167447167318,
#                     0.5311170218526148
#                 ],
#                 [
#                     2.128409593298964,
#                     -0.006167087626742014,
#                     -0.2227476222178468
#                 ],
#                 [
#                     2.915924071430079,
#                     0.13842108452724053,
#                     -0.3703987404056047
#                 ],
#                 [
#                     0.6912918812160269,
#                     0.44013734461492854,
#                     -0.37785008040596424
#                 ],
#                 [
#                     1.426079451987853,
#                     1.006549705553751,
#                     -1.7446605039967076
#                 ],
#                 [
#                     1.8050446013668617,
#                     1.6961329068791668,
#                     -0.6689687173809973
#                 ],
#                 [
#                     1.594625743269204,
#                     0.74377621890282,
#                     -0.22108796836440184
#                 ],
#                 [
#                     2.8570741011123046,
#                     0.446381227855433,
#                     -0.6521185876681632
#                 ],
#                 [
#                     4.884635302183117,
#                     -0.23170905138935485,
#                     0.971960460548338
#                 ],
#                 [
#                     -0.7382684515755626,
#                     -1.0114953633008925,
#                     -0.23246190773145642
#                 ],
#                 [
#                     -1.355228782723304,
#                     -0.6553993920076956,
#                     0.25451140504275804
#                 ],
#                 [
#                     -2.6570903844516343,
#                     -1.0588295953437927,
#                     -0.5084273495092659
#                 ],
#                 [
#                     1.9592525413930932,
#                     -1.2848589428761887,
#                     -1.676624249989149
#                 ],
#                 [
#                     5.052747437872845,
#                     0.46460562907204067,
#                     1.7715190310235973
#                 ],
#                 [
#                     4.373435732471678,
#                     0.011765892372014385,
#                     0.9491432976936834
#                 ],
#                 [
#                     3.6030653596160103,
#                     -1.4354547090388157,
#                     -1.2108218692952482
#                 ],
#                 [
#                     2.367866802000349,
#                     0.9583376345112904,
#                     -1.7109061777200696
#                 ],
#                 [
#                     2.246187999701752,
#                     -0.08917981303511345,
#                     0.1115520225800123
#                 ],
#                 [
#                     2.90517099148659,
#                     1.3089668431858077,
#                     -0.3538239599859691
#                 ],
#                 [
#                     1.698691078012542,
#                     -1.2019887167275354,
#                     -0.30570929560822657
#                 ],
#                 [
#                     3.762890325488472,
#                     0.5419564161980525,
#                     0.03760454222432998
#                 ],
#                 [
#                     1.0395260452238102,
#                     0.4544077390313436,
#                     -0.6223182225577719
#                 ],
#                 [
#                     2.926993450314195,
#                     0.48270709035113885,
#                     -0.613818108204443
#                 ],
#                 [
#                     3.3283952661320577,
#                     0.21114667945482465,
#                     0.693931879651898
#                 ],
#                 [
#                     2.184366970557185,
#                     -0.03507502709492658,
#                     -0.456285195270697
#                 ],
#                 [
#                     2.0040385092164867,
#                     0.3254303931880608,
#                     -0.25391885803912856
#                 ],
#                 [
#                     0.9128748142786903,
#                     0.8472794760894087,
#                     -0.7147563914517967
#                 ],
#                 [
#                     -1.741720524020069,
#                     -0.17795356799218878,
#                     0.23131100412532607
#                 ],
#                 [
#                     -0.6215095988635051,
#                     0.3812705479030389,
#                     0.04776872252969202
#                 ],
#                 [
#                     1.0519171655380715,
#                     0.16852718008209672,
#                     -1.585782292819409
#                 ],
#                 [
#                     0.170843110356984,
#                     1.0613969472189582,
#                     -0.23747514954387566
#                 ],
#                 [
#                     0.24144923036745783,
#                     1.8634452695120034,
#                     -1.3406233959149996
#                 ],
#                 [
#                     4.141870942591995,
#                     0.3844653967455936,

# %%
model = KMeans(n_clusters = 3 , random_state = 529833)
model.fit(data)
# Out:
# KMeans(n_clusters=3, random_state=529833)

# %%
data['分类'] = model.labels_
allCol(data)
data.head()
# Out:
# (569行 ,  4 列)
#    列名           数据类型  NaN 个数  NaN 占比
# 0   一  numpy.float64       0   0.00%
# 1   二  numpy.float64       0   0.00%
# 2   三  numpy.float64       0   0.00%
# 3  分类  numpy.float64       0   0.00%
#           一         二         三  分类
# 0  4.671735 -2.428340 -0.451373   2
# 1  3.212726 -0.975299  0.713303   2
# 2  3.054110 -1.113913  0.129210   2
# 3  1.492991  0.085156 -2.577922   1
# 4  2.640129 -1.969959 -0.095569   2

# %%
val_cnt(data , '分类')
# Out:
#    分类  cnt proportion
# 0   0  359     63.09%
# 1   1  130     22.85%
# 2   2   80     14.06%

# %%
XYZ = [
    (
        float(data['一'].iloc[i]) , 
        float(data['二'].iloc[i]) , 
        float(data['三'].iloc[i])
    )
    for i in range(len(data))
]

labelsInt = [int(la) for la in list(data['分类'])]

LABELS_DICT_Int = {
    0 : '#abd9e9' , 
    1 : 'purple' , 
    2 : '#fdae61' ,
    3 : '#f46d43' , 
    4 : '#4575b4' , 
}

# %%
draw_Scatter3D_clf(
    XYZ , 
    labelsInt , LABELS_DICT_Int , 
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/v5/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="7892e3ff921b40749bb39b7504dfb45f" style="width:1333px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_7892e3ff921b40749bb39b7504dfb45f = echarts.init(
#                     document.getElementById('7892e3ff921b40749bb39b7504dfb45f'), 'white', {renderer: 'canvas'});
#                 var option_7892e3ff921b40749bb39b7504dfb45f = {
#     "backgroundColor": "#FFFFFF",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "name": "\u56fe\u4f8b\u540d\u79f0",
#             "data": [
#                 {
#                     "value": [
#                         4.6717348999367685,
#                         -2.4283402661958045,
#                         -0.4513733894539345
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         3.2127259281360914,
#                         -0.9752992117239003,
#                         0.7133027733369214
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         3.0541097900064673,
#                         -1.113913418113663,
#                         0.12920966895187744
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.4929907705249363,
#                         0.0851559618757375,
#                         -2.577921791680283
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.6401294616122386,
#                         -1.9699586473151616,
#                         -0.09556896734202801
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         0.8902904313041222,
#                         -0.2373644333420317,
#                         -1.498436990822303
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.932024307246461,
#                         -0.1847721119615884,
#                         0.19771582612881503
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.0449457913563422,
#                         0.4456720842693733,
#                         -0.7598431494438521
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.4694134368574778,
#                         0.7521198369428469,
#                         -1.727931755740218
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.6370447098583436,
#                         2.3610187357670287,
#                         -1.7268707966175285
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.155949015214336,
#                         1.335167447167318,
#                         0.5311170218526148
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.128409593298964,
#                         -0.006167087626742014,
#                         -0.2227476222178468
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.915924071430079,
#                         0.13842108452724053,
#                         -0.3703987404056047
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         0.6912918812160269,
#                         0.44013734461492854,
#                         -0.37785008040596424
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.426079451987853,
#                         1.006549705553751,
#                         -1.7446605039967076
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.8050446013668617,
#                         1.6961329068791668,
#                         -0.6689687173809973
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         1.594625743269204,
#                         0.74377621890282,
#                         -0.22108796836440184
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         2.8570741011123046,
#                         0.446381227855433,
#                         -0.6521185876681632
#                     ],
#                     "itemStyle": {
#                         "color": "purple"
#                     }
#                 },
#                 {
#                     "value": [
#                         4.884635302183117,
#                         -0.23170905138935485,
#                         0.971960460548338
#                     ],
#                     "itemStyle": {
#                         "color": "#fdae61"
#                     }
#                 },
#                 {
#                     "value": [
#                         -0.7382684515755626,
#                         -1.0114953633008925,
#                         -0.23246190773145642
#                     ],
#                     "itemStyle": {
#                         "color": "#abd9e9"
#                     }
#                 },
#                 {
#                     "value": [
#                         -1.355228782723304,
#                         -0.6553993920076956,
#                         0.25451140504275804
#                     ],
#                     "itemStyle": {
